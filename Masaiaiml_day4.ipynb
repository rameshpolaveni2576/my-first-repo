# %% [markdown]
# <a href="https://colab.research.google.com/github/rameshpolaveni2576/my-first-repo/blob/main/Masaiaiml_day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welocme")
print("My name is Rivansh")
print("My name is Vrushali Yadav")
# Out:
# welocme
# My name is Rivansh
# My name is Vrushali Yadav

# %%
print("This is our first program in AIML")
# Out:
# This is our first program in AIML

# %%
favourite_book="Maths"
print(favourite_book)
# Out:
# Maths

# %%
favourite_book="Science"

# %%
print(favourite_book)
# Out:
# Science

# %%
a=100
b=100
c="rams"
print(id(a))
print(id(b))
print(id(c))
# Out:
# 11648520
# 11648520
# 135523450241216

# %% [markdown]
# **Keywords in Python**
# false, None, true, and, as, assert, async, await, break, class, continue, def, del, elif, else, except, finally, for, from, global, if, import, in, is, lambda, nonlocal, not, or, pass, raise, return, try, while, with, yield

# %%
class="ramesh"
# Out:
#   File "/tmp/ipykernel_13219/625609523.py", line 1
#     class="ramesh"
#          ^
# SyntaxError: invalid syntax

# %%
rams="my cute name"

# %%
print(5**4)
# Out:
# 625

# %%
total_bill=847
num_friends=5

# %%
print(total_bill/num_friends)
print(total_bill//num_friends)
print(total_bill%num_friends)
# Out:
# 169.4
# 169
# 2

# %%
sub1=91
sub2=84
sub3=83
sub4=97
sub5=97
sub6=92
total=sub1+sub2+sub3+sub4+sub5+sub6

# %%
print(total)
perc=(total/600)*100
print("percentage of marks for Ramesh is",perc,"%")
# Out:
# 544
# percentage of marks for Ramesh is 90.66666666666666 %
